# %% [markdown]
# Dataset source : Yahoo Finance (Yfinance)
#
# Dataset name :  SBIN.NS, TCS.NS, SUNPHARMA.NS, BHARTIARTL.NS, DABUR.NS
#
# Number of companies : 5
#
# Number of records  :  8165
#
# Start date  : 01/01/2020
#
# End date    : 31/07/2026
#
# Number of columns  :  7
#
# Important columns  : 6
#
# Missing-value status  : 0
#
# Duplicate-record status  :  0
