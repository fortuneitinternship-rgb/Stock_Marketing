# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly as ply
import xy as xy
import seaborn as sns
import sklearn as sk
import yfinance as yf

# %%
stocks = {
    "DABUR INDIA LTD": "DABUR.NS",
    "TCS" : "TCS.NS",
    "Bharti Airtel Limited": "BHARTIARTL.NS",
    "STATE BANK OF INDIA": "SBIN.NS",
    "SUNPHARMA": "SUNPHARMA.NS"
}

for company, ticker in stocks.items():
    print(f"Downloading{company}....")
    df = yf.download (ticker ,start="2020-01-01", end="2026-08-03",
                      auto_adjust=False,
                      multi_level_index=False)
    df.to_csv(f"{company}.csv")

print("All files downloaded successfully!")

# %%
df = pd.read_csv("C:/Users/Home/OneDrive/Desktop/Project/Dataset/Raw_Dataset/Bharti Airtel Limited.csv")
print(df.head(5))

df.info()
df.describe()
# Out:
#          Date   Adj Close       Close        High         Low        Open  \
# 0  2020-01-01  427.930878  444.946136  452.013458  441.461548  447.645447
# 1  2020-01-02  429.724548  446.811127  450.933716  445.142456  445.731384
# 2  2020-01-03  429.630096  446.712952  450.737396  443.179321  447.301910
# 3  2020-01-06  424.485138  441.363403  449.019653  436.455536  445.535065
# 4  2020-01-07  420.189728  436.897247  446.909271  434.934113  443.670105
#
#     Volume
# 0  5154996
# 1  4933053
# 2  5154587
# 3  7538915
# 4  4353883
# <class 'pandas.DataFrame'>
# RangeIndex: 1633 entries, 0 to 1632
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1633 non-null   str
#  1   Adj Close  1633 non-null   float64
#  2   Close      1633 non-null   float64
#  3   High       1633 non-null   float64
#  4   Low        1633 non-null   float64
#  5   Open       1633 non-null   float64
#  6   Volume     1633 non-null   int64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 89.4 KB
#          Adj Close        Close         High          Low         Open  \
# count  1633.000000  1633.000000  1633.000000  1633.000000  1633.000000
# mean   1050.101546  1075.209403  1086.793784  1063.738572  1075.555744
# std     542.563704   546.187634   550.038995   542.234557   545.950749
# min     376.790710   390.370789   397.192719   355.083313   390.370789
# 25%     589.913818   611.175171   618.880493   605.629333   611.518738
# 50%     797.609802   822.700012   830.799988   817.549988   824.200012
# 75%    1593.604126  1627.150024  1644.949951  1606.800049  1627.150024
# max    2135.820068  2162.699951  2174.500000  2149.899902  2162.100098
#
#              Volume
# count  1.633000e+03
# mean   1.020299e+07
# std    1.250979e+07
# min    0.000000e+00
# 25%    4.469597e+06
# 50%    6.622800e+06
# 75%    1.142470e+07
# max    1.985470e+08
