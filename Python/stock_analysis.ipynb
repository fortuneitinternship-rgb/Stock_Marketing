# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly as ply
import xy as xy
import seaborn as sns
import sklearn as sk
import yfinance as yf

# %%
'''
stocks = {
    "DABUR INDIA LTD": "DABUR.NS",
    "TCS" : "TCS.NS",
    "Bharti Airtel Limited": "BHARTIARTL.NS",
    "STATE BANK OF INDIA": "SBIN.NS",
    "SUNPHARMA": "SUNPHARMA.NS"
}

for company, ticker in stocks.items():
    print(f"Downloading{company}....")
    df = yf.download (ticker ,start="2020-01-01", end="2026-08-03",
                      auto_adjust=False,
                      multi_level_index=False)
    df.to_csv(f"{company}.csv")

print("All files downloaded successfully!")
'''
# Out:
# '\nstocks = {\n    "DABUR INDIA LTD": "DABUR.NS",\n    "TCS" : "TCS.NS",\n    "Bharti Airtel Limited": "BHARTIARTL.NS",\n    "STATE BANK OF INDIA": "SBIN.NS",\n    "SUNPHARMA": "SUNPHARMA.NS"\n}\n\nfor company, ticker in stocks.items():\n    print(f"Downloading{company}....")\n    df = yf.download (ticker ,start="2020-01-01", end="2026-08-03",\n                      auto_adjust=False,\n                      multi_level_index=False)\n    df.to_csv(f"{company}.csv")\n\nprint("All files downloaded successfully!")\n'

# %%
df = pd.read_csv("C:/Users/Home/OneDrive/Desktop/Project/Dataset/Raw_Dataset/Bharti Airtel Limited.csv")
print(df.head(10))

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)
# Out:
#          Date   Adj Close       Close        High         Low        Open    Volume
# 0  2020-01-01  427.930878  444.946136  452.013458  441.461548  447.645447   5154996
# 1  2020-01-02  429.724548  446.811127  450.933716  445.142456  445.731384   4933053
# 2  2020-01-03  429.630096  446.712952  450.737396  443.179321  447.301910   5154587
# 3  2020-01-06  424.485138  441.363403  449.019653  436.455536  445.535065   7538915
# 4  2020-01-07  420.189758  436.897247  446.909271  434.934113  443.670105   4353883
# 5  2020-01-08  433.170258  450.393860  452.258850  432.234802  434.443329  14118818
# 6  2020-01-09  434.350281  451.620819  466.197144  446.909271  459.767853  18180867
# 7  2020-01-10  431.423798  448.577942  457.363007  445.829559  456.234192  37724966
# 8  2020-01-13  442.657806  460.258636  461.632843  445.878632  450.541077  15206224
# 9  2020-01-14  443.082642  460.700348  463.939545  458.001038  460.258636   8238486

# %%
# Read All Files

airtel = pd.read_csv("C:/Users/Home/OneDrive/Desktop/Project/Dataset/Raw_Dataset/Bharti Airtel Limited.csv")
tcs = pd.read_csv("C:/Users/Home/OneDrive/Desktop/Project/Dataset/Raw_Dataset/TCS.csv")
sbin = pd.read_csv("C:/Users/Home/OneDrive/Desktop/Project/Dataset/Raw_Dataset/STATE BANK OF INDIA.csv")
dabur = pd.read_csv("C:/Users/Home/OneDrive/Desktop/Project/Dataset/Raw_Dataset/DABUR INDIA LTD.csv")
sunpharma = pd.read_csv("C:/Users/Home/OneDrive/Desktop/Project/Dataset/Raw_Dataset/SUNPHARMA.csv")

# %%
# Add New Column[Company] to each file 

airtel["Company"] = "Airtel"
dabur["Company"] = "Dabur"
tcs["Company"] = "TCS"
sbin["Company"] = "SBIN"
sunpharma["Company"] = "Sun Pharma"

# %%
# Merge All the DataFrames into a single DataFrame

stock_data = pd.concat([airtel, dabur, tcs, sbin, sunpharma], ignore_index = True)

# Drop the "Company" column from the DataFrame if it exists

stock_data.drop(columns=["Comapny"], errors="ignore", inplace=True)

#stock_data.to_csv
stock_data.to_csv("stock_market_master.csv", index = False)

# %%
# Check the shape of the merged DataFrame

stock_data.shape
print("Shape of the merged DataFrame:", stock_data.shape)

# Check dataset Information
stock_data.info()
# Out:
# Shape of the merged DataFrame: (8165, 8)
# <class 'pandas.DataFrame'>
# RangeIndex: 8165 entries, 0 to 8164
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8165 non-null   str
#  1   Adj Close  8165 non-null   float64
#  2   Close      8165 non-null   float64
#  3   High       8165 non-null   float64
#  4   Low        8165 non-null   float64
#  5   Open       8165 non-null   float64
#  6   Volume     8165 non-null   int64
#  7   Company    8165 non-null   str
# dtypes: float64(5), int64(1), str(2)
# memory usage: 510.4 KB

# %%
df = pd.read_csv("stock_market_master.csv")

df.head(5)
df.tail(5)
df.shape
#df.columns
#df.info()
#df.describe()
# Out:
# (8165, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8165 entries, 0 to 8164
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8165 non-null   str
#  1   Adj Close  8165 non-null   float64
#  2   Close      8165 non-null   float64
#  3   High       8165 non-null   float64
#  4   Low        8165 non-null   float64
#  5   Open       8165 non-null   float64
#  6   Volume     8165 non-null   int64
#  7   Company    8165 non-null   str
# dtypes: float64(5), int64(1), str(2)
# memory usage: 510.4 KB

# %%
# Rename Column Names

df.rename(columns = {"Adj Close":"Adj_Close"}, inplace = True)

# Change Column Data Type

df["Date"] = pd.to_datetime(df["Date"])

# Adding Local Timezone to the Date Column

df["Date"] = df["Date"].dt.tz_localize("Asia/Kolkata")

# %%
# Normalize the Date Column (01-02-2020, 02/03/2024)

df["Date"] = pd.to_datetime(df["Date"], errors ="coerce", dayfirst=True)

df["Date"] = df["Date"].dt.tz_localize(None)

# Extract Year, Month, and Day, Quarter from the Date Column

df["Year"] = df["Date"].dt.year

df["Month"] = df["Date"].dt.month

df["Day"] = df["Date"].dt.day

df["Weekday"] = df["Date"].dt.day_name()

df["Weekday_Num"] = df["Date"].dt.weekday

df["Quarter"] = df["Date"].dt.quarter

df.head()
# Out:
#         Date   Adj_Close       Close        High         Low        Open   Volume Company  Year  Month  Day    Weekday  Weekday_Num  Quarter
# 0 2020-01-01  427.930878  444.946136  452.013458  441.461548  447.645447  5154996  Airtel  2020      1    1  Wednesday            2        1
# 1 2020-01-02  429.724548  446.811127  450.933716  445.142456  445.731384  4933053  Airtel  2020      1    2   Thursday            3        1
# 2 2020-01-03  429.630096  446.712952  450.737396  443.179321  447.301910  5154587  Airtel  2020      1    3     Friday            4        1
# 3 2020-01-06  424.485138  441.363403  449.019653  436.455536  445.535065  7538915  Airtel  2020      1    6     Monday            0        1
# 4 2020-01-07  420.189758  436.897247  446.909271  434.934113  443.670105  4353883  Airtel  2020      1    7    Tuesday            1        1
