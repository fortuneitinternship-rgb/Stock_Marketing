# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly as ply
import xy as xy
import seaborn as sns
import sklearn as sk
import yfinance as yf

# %%
stocks = {
    "DABUR INDIA LTD": "DABUR.NS",
    "TCS" : "TCS.NS",
    "Bharti Airtel Limited": "BHARTIARTL.NS",
    "STATE BANK OF INDIA": "SBIN.NS",
    "SUNPHARMA": "SUNPHARMA.NS"
}

for company, ticker in stocks.items():
    print(f"Downloading{company}....")
    df = yf.download (ticker ,start="2020-01-01", end="2026-08-03",
                      auto_adjust=False,
                      multi_level_index=False)
    df.to_csv(f"{company}.csv")

print("All files downloaded successfully!")

# %%
df = yf.download("SBIN.NS", start="2020-01-01", end="2026-08-03")
df.head()

df.to_csv("SBIN.NS.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = yf.download("TCS.NS", start="2020-01-01", end="2026-08-03")
df.head()

df.to_csv("TCS.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.read_csv("C:/Users/Home/OneDrive/Desktop/Project/Dataset/Raw_Dataset/Bharti Airtel Limited.csv")
print(df.head(5))
# Out:
#          Date   Adj Close       Close        High         Low        Open  \
# 0  2020-01-01  427.930878  444.946136  452.013458  441.461548  447.645447
# 1  2020-01-02  429.724548  446.811127  450.933716  445.142456  445.731384
# 2  2020-01-03  429.630096  446.712952  450.737396  443.179321  447.301910
# 3  2020-01-06  424.485138  441.363403  449.019653  436.455536  445.535065
# 4  2020-01-07  420.189728  436.897247  446.909271  434.934113  443.670105
#
#     Volume
# 0  5154996
# 1  4933053
# 2  5154587
# 3  7538915
# 4  4353883
